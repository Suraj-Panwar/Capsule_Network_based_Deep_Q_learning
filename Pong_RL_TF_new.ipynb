# %%
import tensorflow as tf
import cv2
import sys
import pong_fun as game
import random
import time 
import numpy as np
from collections import deque

# %%
epsilon = 1e-9
iter_routing = 1
train_freq = 20

# %%
def squash(vector):
    vec_squared_norm = reduce_sum(tf.square(vector), -2, keepdims=True)
    scalar_factor = vec_squared_norm / (1 + vec_squared_norm) / tf.sqrt(vec_squared_norm + epsilon)
    vec_squashed = scalar_factor * vector  # element-wise
    return(vec_squashed)
def routing(input, b_IJ):
    # W: [1, num_caps_i, num_caps_j * len_v_j, len_u_j, 1]
    W = tf.get_variable('Weight', shape=(1, 1152, 160, 8, 1), dtype=tf.float32,
                        initializer=tf.random_normal_initializer(stddev=0.01))
    biases = tf.get_variable('bias', shape=(1, 1, 10, 16, 1))

    # Eq.2, calc u_hat
    # Since tf.matmul is a time-consuming op,
    # A better solution is using element-wise multiply, reduce_sum and reshape
    # ops instead. Matmul [a, b] x [b, c] is equal to a series ops as
    # element-wise multiply [a*c, b] * [a*c, b], reduce_sum at axis=1 and
    # reshape to [a, c]
    input = tf.tile(input, [1, 1, 160, 1, 1])
    #assert input.get_shape() == [cfg.batch_size, 1152, 160, 8, 1]

    u_hat = reduce_sum(W * input, axis=3, keepdims=True)
    u_hat = tf.reshape(u_hat, shape=[-1, 1152, 10, 16, 1])
    #assert u_hat.get_shape() == [cfg.batch_size, 1152, 10, 16, 1]

    # In forward, u_hat_stopped = u_hat; in backward, no gradient passed back from u_hat_stopped to u_hat
    u_hat_stopped = tf.stop_gradient(u_hat, name='stop_gradient')

    # line 3,for r iterations do
    for r_iter in range(iter_routing):
        with tf.variable_scope('iter_' + str(r_iter)):
            # line 4:
            # => [batch_size, 1152, 10, 1, 1]
            c_IJ = softmax(b_IJ, axis=2)

            # At last iteration, use `u_hat` in order to receive gradients from the following graph
            if r_iter == iter_routing - 1:
                # line 5:
                # weighting u_hat with c_IJ, element-wise in the last two dims
                # => [batch_size, 1152, 10, 16, 1]
                s_J = tf.multiply(c_IJ, u_hat)
                # then sum in the second dim, resulting in [batch_size, 1, 10, 16, 1]
                s_J = reduce_sum(s_J, axis=1, keepdims=True) + biases
                #assert s_J.get_shape() == [cfg.batch_size, 1, 10, 16, 1]

                # line 6:
                # squash using Eq.1,
                v_J = squash(s_J)
                #assert v_J.get_shape() == [cfg.batch_size, 1, 10, 16, 1]
            elif r_iter < iter_routing - 1:  # Inner iterations, do not apply backpropagation
                s_J = tf.multiply(c_IJ, u_hat_stopped)
                s_J = reduce_sum(s_J, axis=1, keepdims=True) + biases
                v_J = squash(s_J)

                # line 7:
                # reshape & tile v_j from [batch_size ,1, 10, 16, 1] to [batch_size, 1152, 10, 16, 1]
                # then matmul in the last tow dim: [16, 1].T x [16, 1] => [1, 1], reduce mean in the
                # batch_size dim, resulting in [1, 1152, 10, 1, 1]
                v_J_tiled = tf.tile(v_J, [1, 1152, 1, 1, 1])
                u_produce_v = reduce_sum(u_hat_stopped * v_J_tiled, axis=3, keepdims=True)
                #assert u_produce_v.get_shape() == [cfg.batch_size, 1152, 10, 1, 1]

                # b_IJ += tf.reduce_sum(u_produce_v, axis=0, keep_dims=True)
                b_IJ += u_produce_v

    return(v_J)
# For version compatibility
def reduce_sum(input_tensor, axis=None, keepdims=False):
    try:
        return tf.reduce_sum(input_tensor, axis=axis, keepdims=keepdims)
    except:
        return tf.reduce_sum(input_tensor, axis=axis, keep_dims=keepdims)
# For version compatibility
def softmax(logits, axis=None):
    try:
        return tf.nn.softmax(logits, axis=axis)
    except:
        return tf.nn.softmax(logits, dim=axis)

# %%
GAME = 'pong' # the name of the game being played for log files
ACTIONS = 6 # number of valid actions
GAMMA = 0.99 # decay rate of past observations
OBSERVE = 1000. # timesteps to observe before training
EXPLORE = 5000. # frames over which to anneal epsilon
FINAL_EPSILON = 0.05 # final value of epsilon
INITIAL_EPSILON = 1.0 # starting value of epsilon
REPLAY_MEMORY = 100000 # number of previous transitions to remember
BATCH = 32 # size of minibatch
K = 1 # only select an action every Kth frame, repeat prev for others

# %%
def createNetwork():
    # input layer
    s= tf.placeholder("float", [None, 84, 84, 4])
    coeff = tf.placeholder(tf.float32, shape=(None, 1152, 10, 1, 1))
    ####################### New Network Configuration #####################    
    w_initializer, b_initializer = tf.random_normal_initializer(0., 0.01), tf.constant_initializer(0.01)
    w1 = tf.get_variable('w1',[8, 8, 4, 256],initializer=w_initializer)
    b1 = tf.get_variable('b1',[256],initializer=b_initializer)
    # Conv1, [batch_size, 20, 20, 256]
    l1 = tf.nn.conv2d(s, w1, strides=[1, 4, 4, 1], padding="VALID")
    conv1 = tf.nn.relu(tf.nn.bias_add(l1, b1))
    conv1 = tf.reshape(conv1,[-1,20,20,256])
    capsules = tf.contrib.layers.conv2d(conv1, 32 * 8,kernel_size=9, stride=2, padding="VALID",
                    activation_fn = tf.nn.relu,
                    weights_initializer = tf.contrib.layers.xavier_initializer(uniform=False),
                    biases_initializer=tf.constant_initializer(0))
    
    capsules = tf.reshape(capsules, (-1, 1152, 8, 1)) #Reshape to(batch_szie, 1152, 8, 1)
    capsules = squash(capsules)
    input_fc = tf.reshape(capsules, shape=(-1, 1152, 1, capsules.shape[-2].value, 1))
    caps2 = routing(input_fc, coeff)
    vector_j = tf.reshape(caps2, shape=(-1, 160))
    fc1 = tf.contrib.layers.fully_connected(vector_j, num_outputs=30, activation_fn=tf.nn.relu)
    q_eval = tf.contrib.layers.fully_connected(fc1, num_outputs=ACTIONS, activation_fn=None)
    readout = q_eval
    return s, coeff, readout

# %%
def trainNetwork(s, coeff, readout, sess):
    tick = time.time()
    # define the cost function
    a = tf.placeholder("float", [None, ACTIONS])
    y = tf.placeholder("float", [None])
    readout_action = tf.reduce_sum(tf.multiply(readout, a), reduction_indices = 1)
    cost = tf.reduce_mean(tf.square(y - readout_action))
    train_step = tf.train.AdamOptimizer(1e-4).minimize(cost)

    # open up a game state to communicate with emulator
    game_state = game.GameState()
    # store the previous observations in replay memory
    D = deque()

    # printing
#     a_file = open("logs_" + GAME + "/readout.txt", 'w')
#     h_file = open("logs_" + GAME + "/hidden.txt", 'w')

    # get the first state by doing nothing and preprocess the image to 80x80x4
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] = 1
    x_t, r_0, terminal, bar1_score, bar2_score = game_state.frame_step(do_nothing)
    x_t = cv2.cvtColor(cv2.resize(x_t, (84, 84)), cv2.COLOR_BGR2GRAY)
    ret, x_t = cv2.threshold(x_t,1,255,cv2.THRESH_BINARY)
    s_t = np.stack((x_t, x_t, x_t, x_t), axis = 2)  
    # saving and loading networks
    saver = tf.train.Saver()
    #sess.run(tf.initialize_all_variables())
    sess.run(tf.global_variables_initializer())

    b_IJ1 = np.zeros((1, 1152, 10, 1, 1)).astype(np.float32) # batch_size=1
    b_IJ2 = np.zeros((BATCH, 1152, 10, 1, 1)).astype(np.float32) # batch_size=BATCH
    epsilon = INITIAL_EPSILON
    t = 0
    episode = 0
    while "pigs" != "fly":
        # choose an action epsilon greedily
        # readout_t = readout.eval(feed_dict = {s : [s_t].reshape((1,80,80,4))})[0]
        
        readout_t = readout.eval(feed_dict = {s:s_t.reshape((1,84,84,4)), coeff:b_IJ1})
        
        a_t = np.zeros([ACTIONS])
        action_index = 0
        if random.random() <= epsilon or t <= OBSERVE:
            action_index = random.randrange(ACTIONS)
            a_t[action_index] = 1
        else:
            action_index = np.argmax(readout_t)
            a_t[action_index] = 1

        # scale down epsilon
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        for i in range(0, K):
            # run the selected action and observe next state and reward
            x_t1_col, r_t, terminal, bar1_score, bar2_score = game_state.frame_step(a_t)
            if(terminal == 1):
                episode +=1
            x_t1 = cv2.cvtColor(cv2.resize(x_t1_col, (84, 84)), cv2.COLOR_BGR2GRAY)
            ret, x_t1 = cv2.threshold(x_t1,1,255,cv2.THRESH_BINARY)
            x_t1 = np.reshape(x_t1, (84, 84, 1))
            s_t1 = np.append(x_t1, s_t[:,:,0:3], axis = 2)

            # store the transition in D
            D.append((s_t, a_t, r_t, s_t1, terminal))
            if len(D) > REPLAY_MEMORY:
                D.popleft()
        
        # only train if done observing
        if t > OBSERVE and t%train_freq==0:
            # sample a minibatch to train on
            minibatch = random.sample(D, BATCH)

            # get the batch variables
            s_j_batch = [d[0] for d in minibatch]
            a_batch = [d[1] for d in minibatch]
            r_batch = [d[2] for d in minibatch]
            s_j1_batch = [d[3] for d in minibatch]

            y_batch = []
            readout_j1_batch = readout.eval(feed_dict = {s:s_j1_batch, coeff:b_IJ2 })
            #readout_j1_batch = readout.eval(feed_dict = {s : s_j1_batch})
            for i in range(0, len(minibatch)):
                # if terminal only equals reward
                if minibatch[i][4]:
                    y_batch.append(r_batch[i])
                else:
                    y_batch.append(r_batch[i] + GAMMA * np.max(readout_j1_batch[i]))

            # perform gradient step
            train_step.run(feed_dict = {
                y : y_batch,
                a : a_batch,
                s : s_j_batch,
                coeff: b_IJ2})

        # update the old values
        s_t = s_t1
        t += 1

        # save progress every 10000 iterations
        if t % 10000 == 0:
            saver.save(sess, 'saved_networks/' + GAME + '-dqn', global_step = t)
        if r_t!= 0:
            print ("TIMESTEP", t, "/ EPISODE", episode, "/ bar1_score", bar1_score, "/ bar2_score", bar2_score, "/ REWARD", r_t, "/ Q_MAX %e" % np.max(readout_t))

        if(bar1_score - bar2_score > 17): 
            print("Game_Ends_in Time:",int(time.time() - tick))
            break;   
        if(bar1_score - bar2_score > 16):
            print("Game_Mid_in Time:",int(time.time() - tick))

# %%
def playGame():
    tf.reset_default_graph()
    sess = tf.InteractiveSession()
    s, coeff, readout = createNetwork()
    trainNetwork(s, coeff, readout, sess)

# %%
def main():
    playGame()

if __name__ == "__main__":
    tick = time.time()
    main()
    print("Game_Ends_in Time:",int(time.time() - tick))
    print("____________ END HERE _____________")
# Out:
# TIMESTEP 297 / EPISODE 0 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 5.432077e-02
# TIMESTEP 343 / EPISODE 0 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 5.572042e-02
# TIMESTEP 389 / EPISODE 0 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 5.557521e-02
# TIMESTEP 435 / EPISODE 0 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 5.894655e-02
# TIMESTEP 566 / EPISODE 0 / bar1_score 1 / bar2_score 4 / REWARD 1 / Q_MAX 5.353391e-02
# TIMESTEP 695 / EPISODE 0 / bar1_score 1 / bar2_score 5 / REWARD -1 / Q_MAX 4.421923e-02
# TIMESTEP 741 / EPISODE 0 / bar1_score 1 / bar2_score 6 / REWARD -1 / Q_MAX 4.946889e-02
# TIMESTEP 787 / EPISODE 0 / bar1_score 1 / bar2_score 7 / REWARD -1 / Q_MAX 5.191492e-02
# TIMESTEP 833 / EPISODE 0 / bar1_score 1 / bar2_score 8 / REWARD -1 / Q_MAX 4.733207e-02
# TIMESTEP 879 / EPISODE 0 / bar1_score 1 / bar2_score 9 / REWARD -1 / Q_MAX 4.732193e-02
# TIMESTEP 925 / EPISODE 0 / bar1_score 1 / bar2_score 10 / REWARD -1 / Q_MAX 5.138817e-02
# TIMESTEP 971 / EPISODE 0 / bar1_score 1 / bar2_score 11 / REWARD -1 / Q_MAX 4.902551e-02
# TIMESTEP 1017 / EPISODE 0 / bar1_score 1 / bar2_score 12 / REWARD -1 / Q_MAX 4.891831e-02
# TIMESTEP 1063 / EPISODE 0 / bar1_score 1 / bar2_score 13 / REWARD -1 / Q_MAX 3.013059e-01
# TIMESTEP 1109 / EPISODE 0 / bar1_score 1 / bar2_score 14 / REWARD -1 / Q_MAX 3.758256e-01
# TIMESTEP 1155 / EPISODE 0 / bar1_score 1 / bar2_score 15 / REWARD -1 / Q_MAX 4.974599e-01
# TIMESTEP 1201 / EPISODE 0 / bar1_score 1 / bar2_score 16 / REWARD -1 / Q_MAX 6.431024e-01
# TIMESTEP 1247 / EPISODE 0 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX 8.098021e-01
# TIMESTEP 1293 / EPISODE 0 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX 8.467785e-01
# TIMESTEP 1339 / EPISODE 0 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX 9.516844e-01
# TIMESTEP 1385 / EPISODE 1 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 9.908365e-01
# TIMESTEP 1431 / EPISODE 1 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.077666e+00
# TIMESTEP 1477 / EPISODE 1 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.055717e+00
# TIMESTEP 1523 / EPISODE 1 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.134779e+00
# TIMESTEP 1569 / EPISODE 1 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.156871e+00
# TIMESTEP 1615 / EPISODE 1 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.170557e+00
# TIMESTEP 1661 / EPISODE 1 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.200703e+00
# TIMESTEP 1707 / EPISODE 1 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.219188e+00
# TIMESTEP 1753 / EPISODE 1 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.245956e+00
# TIMESTEP 1799 / EPISODE 1 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.262194e+00
# TIMESTEP 1845 / EPISODE 1 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.291691e+00
# TIMESTEP 1891 / EPISODE 1 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.282302e+00
# TIMESTEP 1937 / EPISODE 1 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.271753e+00
# TIMESTEP 1983 / EPISODE 1 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.305304e+00
# TIMESTEP 2029 / EPISODE 1 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.325510e+00
# TIMESTEP 2075 / EPISODE 1 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.333260e+00
# TIMESTEP 2121 / EPISODE 1 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.330485e+00
# TIMESTEP 2334 / EPISODE 1 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.414423e+00
# TIMESTEP 2380 / EPISODE 1 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.419590e+00
# TIMESTEP 2426 / EPISODE 1 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.391290e+00
# TIMESTEP 2472 / EPISODE 2 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.399372e+00
# TIMESTEP 2518 / EPISODE 2 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.415557e+00
# TIMESTEP 2564 / EPISODE 2 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.410880e+00
# TIMESTEP 2610 / EPISODE 2 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.433819e+00
# TIMESTEP 2656 / EPISODE 2 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.444590e+00
# TIMESTEP 2702 / EPISODE 2 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.458701e+00
# TIMESTEP 2748 / EPISODE 2 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.460229e+00
# TIMESTEP 2794 / EPISODE 2 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.462120e+00
# TIMESTEP 2840 / EPISODE 2 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.453582e+00
# TIMESTEP 2886 / EPISODE 2 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.452136e+00
# TIMESTEP 3015 / EPISODE 2 / bar1_score 1 / bar2_score 9 / REWARD 1 / Q_MAX 1.487498e+00
# TIMESTEP 3144 / EPISODE 2 / bar1_score 1 / bar2_score 10 / REWARD -1 / Q_MAX 1.451383e+00
# TIMESTEP 3190 / EPISODE 2 / bar1_score 1 / bar2_score 11 / REWARD -1 / Q_MAX 1.472294e+00
# TIMESTEP 3236 / EPISODE 2 / bar1_score 1 / bar2_score 12 / REWARD -1 / Q_MAX 1.457235e+00
# TIMESTEP 3282 / EPISODE 2 / bar1_score 1 / bar2_score 13 / REWARD -1 / Q_MAX 1.522221e+00
# TIMESTEP 3328 / EPISODE 2 / bar1_score 1 / bar2_score 14 / REWARD -1 / Q_MAX 1.552956e+00
# TIMESTEP 3374 / EPISODE 2 / bar1_score 1 / bar2_score 15 / REWARD -1 / Q_MAX 1.544200e+00
# TIMESTEP 3420 / EPISODE 2 / bar1_score 1 / bar2_score 16 / REWARD -1 / Q_MAX 1.552811e+00
# TIMESTEP 3551 / EPISODE 2 / bar1_score 2 / bar2_score 16 / REWARD 1 / Q_MAX 1.484902e+00
# TIMESTEP 3680 / EPISODE 2 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 1.573827e+00
# TIMESTEP 3726 / EPISODE 2 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 1.584689e+00
# TIMESTEP 3772 / EPISODE 2 / bar1_score 2 / bar2_score 19 / REWARD -1 / Q_MAX 1.621906e+00
# TIMESTEP 3818 / EPISODE 3 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.638844e+00
# TIMESTEP 3864 / EPISODE 3 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.616549e+00
# TIMESTEP 3910 / EPISODE 3 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.607844e+00
# TIMESTEP 3956 / EPISODE 3 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.624117e+00
# TIMESTEP 4002 / EPISODE 3 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.624515e+00
# TIMESTEP 4048 / EPISODE 3 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.635891e+00
# TIMESTEP 4094 / EPISODE 3 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.652000e+00
# TIMESTEP 4140 / EPISODE 3 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.633867e+00
# TIMESTEP 4186 / EPISODE 3 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.649892e+00
# TIMESTEP 4232 / EPISODE 3 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.650648e+00
# TIMESTEP 4278 / EPISODE 3 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.650564e+00
# TIMESTEP 4324 / EPISODE 3 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.654069e+00
# TIMESTEP 4370 / EPISODE 3 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.650215e+00
# TIMESTEP 4416 / EPISODE 3 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.638813e+00
# TIMESTEP 4462 / EPISODE 3 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.671350e+00
# TIMESTEP 4676 / EPISODE 3 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.669769e+00
# TIMESTEP 4722 / EPISODE 3 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.665812e+00
# TIMESTEP 4768 / EPISODE 3 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.651704e+00
# TIMESTEP 4814 / EPISODE 3 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.683805e+00
# TIMESTEP 4860 / EPISODE 3 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.654359e+00
# TIMESTEP 4906 / EPISODE 4 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.677549e+00
# TIMESTEP 4952 / EPISODE 4 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.686489e+00
# TIMESTEP 5081 / EPISODE 4 / bar1_score 1 / bar2_score 1 / REWARD 1 / Q_MAX 1.643692e+00
# TIMESTEP 5463 / EPISODE 4 / bar1_score 2 / bar2_score 1 / REWARD 1 / Q_MAX 1.665904e+00
# TIMESTEP 5592 / EPISODE 4 / bar1_score 2 / bar2_score 2 / REWARD -1 / Q_MAX 1.711790e+00
# TIMESTEP 5638 / EPISODE 4 / bar1_score 2 / bar2_score 3 / REWARD -1 / Q_MAX 1.725747e+00
# TIMESTEP 5684 / EPISODE 4 / bar1_score 2 / bar2_score 4 / REWARD -1 / Q_MAX 1.739980e+00
# TIMESTEP 5730 / EPISODE 4 / bar1_score 2 / bar2_score 5 / REWARD -1 / Q_MAX 1.726184e+00
# TIMESTEP 5776 / EPISODE 4 / bar1_score 2 / bar2_score 6 / REWARD -1 / Q_MAX 1.718101e+00
# TIMESTEP 5822 / EPISODE 4 / bar1_score 2 / bar2_score 7 / REWARD -1 / Q_MAX 1.748165e+00
# TIMESTEP 5868 / EPISODE 4 / bar1_score 2 / bar2_score 8 / REWARD -1 / Q_MAX 1.750634e+00
# TIMESTEP 5914 / EPISODE 4 / bar1_score 2 / bar2_score 9 / REWARD -1 / Q_MAX 1.772846e+00
# TIMESTEP 5960 / EPISODE 4 / bar1_score 2 / bar2_score 10 / REWARD -1 / Q_MAX 1.759824e+00
# TIMESTEP 6006 / EPISODE 4 / bar1_score 2 / bar2_score 11 / REWARD -1 / Q_MAX 1.764301e+00
# TIMESTEP 6052 / EPISODE 4 / bar1_score 2 / bar2_score 12 / REWARD -1 / Q_MAX 1.795268e+00
# TIMESTEP 6098 / EPISODE 4 / bar1_score 2 / bar2_score 13 / REWARD -1 / Q_MAX 1.813326e+00
# TIMESTEP 6144 / EPISODE 4 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 1.785871e+00
# TIMESTEP 6190 / EPISODE 4 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 1.797716e+00
# TIMESTEP 6236 / EPISODE 4 / bar1_score 2 / bar2_score 16 / REWARD -1 / Q_MAX 1.799374e+00
# TIMESTEP 6282 / EPISODE 4 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 1.840274e+00
# TIMESTEP 6328 / EPISODE 4 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 1.821532e+00
# TIMESTEP 6374 / EPISODE 4 / bar1_score 2 / bar2_score 19 / REWARD -1 / Q_MAX 1.801343e+00
# TIMESTEP 6420 / EPISODE 5 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.799023e+00
# TIMESTEP 6466 / EPISODE 5 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.811231e+00
# TIMESTEP 6512 / EPISODE 5 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.821898e+00
# TIMESTEP 6558 / EPISODE 5 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.826114e+00
# TIMESTEP 6604 / EPISODE 5 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.832587e+00
# TIMESTEP 6650 / EPISODE 5 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.815392e+00
# TIMESTEP 6696 / EPISODE 5 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.815930e+00
# TIMESTEP 6742 / EPISODE 5 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.827699e+00
# TIMESTEP 6788 / EPISODE 5 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.810770e+00
# TIMESTEP 6834 / EPISODE 5 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.823438e+00
# TIMESTEP 6880 / EPISODE 5 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.831469e+00
# TIMESTEP 6926 / EPISODE 5 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.820895e+00
# TIMESTEP 6972 / EPISODE 5 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.815279e+00
# TIMESTEP 7018 / EPISODE 5 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.815548e+00
# TIMESTEP 7064 / EPISODE 5 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.834735e+00
# TIMESTEP 7110 / EPISODE 5 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.826076e+00
# TIMESTEP 7156 / EPISODE 5 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.823600e+00
# TIMESTEP 7202 / EPISODE 5 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.810522e+00
# TIMESTEP 7248 / EPISODE 5 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.826729e+00
# TIMESTEP 7294 / EPISODE 5 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.814062e+00
# TIMESTEP 7340 / EPISODE 6 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.826166e+00
# TIMESTEP 7386 / EPISODE 6 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.803446e+00
# TIMESTEP 7432 / EPISODE 6 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.799837e+00
# TIMESTEP 7478 / EPISODE 6 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.840037e+00
# TIMESTEP 7524 / EPISODE 6 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.823130e+00
# TIMESTEP 7570 / EPISODE 6 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.841740e+00
# TIMESTEP 7616 / EPISODE 6 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.835458e+00
# TIMESTEP 7662 / EPISODE 6 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.806291e+00
# TIMESTEP 7708 / EPISODE 6 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.854199e+00
# TIMESTEP 7754 / EPISODE 6 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.832707e+00
# TIMESTEP 7800 / EPISODE 6 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.845247e+00
# TIMESTEP 7846 / EPISODE 6 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.818768e+00
# TIMESTEP 7892 / EPISODE 6 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.825573e+00
# TIMESTEP 7938 / EPISODE 6 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.813558e+00
# TIMESTEP 7984 / EPISODE 6 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.840618e+00
# TIMESTEP 8030 / EPISODE 6 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.833057e+00
# TIMESTEP 8076 / EPISODE 6 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.850372e+00
# TIMESTEP 8122 / EPISODE 6 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.809565e+00
# TIMESTEP 8168 / EPISODE 6 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.868813e+00
# TIMESTEP 8214 / EPISODE 6 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.812918e+00
# TIMESTEP 8260 / EPISODE 7 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.850884e+00
# TIMESTEP 8306 / EPISODE 7 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.798425e+00
# TIMESTEP 8352 / EPISODE 7 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.799435e+00
# TIMESTEP 8398 / EPISODE 7 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.805622e+00
# TIMESTEP 8444 / EPISODE 7 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.788822e+00
# TIMESTEP 8490 / EPISODE 7 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.801347e+00
# TIMESTEP 8536 / EPISODE 7 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.783861e+00
# TIMESTEP 8582 / EPISODE 7 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.829193e+00
# TIMESTEP 8628 / EPISODE 7 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.792483e+00
# TIMESTEP 8674 / EPISODE 7 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.797300e+00
# TIMESTEP 8720 / EPISODE 7 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.812453e+00
# TIMESTEP 8766 / EPISODE 7 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.793433e+00
# TIMESTEP 8812 / EPISODE 7 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.815378e+00
# TIMESTEP 8858 / EPISODE 7 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.812145e+00
# TIMESTEP 8904 / EPISODE 7 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.811040e+00
# TIMESTEP 8950 / EPISODE 7 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.806693e+00
# TIMESTEP 8996 / EPISODE 7 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.798380e+00
# TIMESTEP 9042 / EPISODE 7 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.824296e+00
# TIMESTEP 9088 / EPISODE 7 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.810245e+00
# TIMESTEP 9134 / EPISODE 7 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.823246e+00
# TIMESTEP 9180 / EPISODE 8 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.811297e+00
# TIMESTEP 9226 / EPISODE 8 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.826660e+00
# TIMESTEP 9272 / EPISODE 8 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.835792e+00
# TIMESTEP 9318 / EPISODE 8 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.826510e+00
# TIMESTEP 9364 / EPISODE 8 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.820011e+00
# TIMESTEP 9410 / EPISODE 8 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.826607e+00
# TIMESTEP 9456 / EPISODE 8 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.819170e+00
# TIMESTEP 9502 / EPISODE 8 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.808824e+00
# TIMESTEP 9548 / EPISODE 8 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.847026e+00
# TIMESTEP 9594 / EPISODE 8 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.827463e+00
# TIMESTEP 9640 / EPISODE 8 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.859477e+00
# TIMESTEP 9686 / EPISODE 8 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.801844e+00
# TIMESTEP 9732 / EPISODE 8 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.806355e+00
# TIMESTEP 9778 / EPISODE 8 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.803637e+00
# TIMESTEP 9824 / EPISODE 8 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.788859e+00
# TIMESTEP 9870 / EPISODE 8 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.808990e+00
# TIMESTEP 9916 / EPISODE 8 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.795641e+00
# TIMESTEP 9962 / EPISODE 8 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.780835e+00
# TIMESTEP 10008 / EPISODE 8 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.818945e+00
# TIMESTEP 10054 / EPISODE 8 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.849146e+00
# TIMESTEP 10100 / EPISODE 9 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.845489e+00
# TIMESTEP 10146 / EPISODE 9 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.865047e+00
# TIMESTEP 10192 / EPISODE 9 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.849055e+00
# TIMESTEP 10238 / EPISODE 9 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.855969e+00
# TIMESTEP 10284 / EPISODE 9 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.868932e+00
# TIMESTEP 10330 / EPISODE 9 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.871479e+00
# TIMESTEP 10376 / EPISODE 9 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.880121e+00
# TIMESTEP 10422 / EPISODE 9 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.884903e+00
# TIMESTEP 10468 / EPISODE 9 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.856364e+00
# TIMESTEP 10514 / EPISODE 9 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.887941e+00
# TIMESTEP 10560 / EPISODE 9 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.889826e+00
# TIMESTEP 10606 / EPISODE 9 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.877875e+00
# TIMESTEP 10652 / EPISODE 9 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.865077e+00
# TIMESTEP 10698 / EPISODE 9 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.886816e+00
# TIMESTEP 10744 / EPISODE 9 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.881166e+00
# TIMESTEP 10790 / EPISODE 9 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.904340e+00
# TIMESTEP 10836 / EPISODE 9 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.883965e+00
# TIMESTEP 10882 / EPISODE 9 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.895324e+00
# TIMESTEP 10928 / EPISODE 9 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.872735e+00
# TIMESTEP 10974 / EPISODE 9 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.900925e+00
# TIMESTEP 11020 / EPISODE 10 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.867986e+00
# TIMESTEP 11066 / EPISODE 10 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.930993e+00
# TIMESTEP 11112 / EPISODE 10 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.878263e+00
# TIMESTEP 11158 / EPISODE 10 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.912615e+00
# TIMESTEP 11204 / EPISODE 10 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.890924e+00
# TIMESTEP 11250 / EPISODE 10 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.871164e+00
# TIMESTEP 11296 / EPISODE 10 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.881016e+00
# TIMESTEP 11342 / EPISODE 10 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.870448e+00
# TIMESTEP 11388 / EPISODE 10 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.826545e+00
# TIMESTEP 11434 / EPISODE 10 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.845223e+00
# TIMESTEP 11480 / EPISODE 10 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.833375e+00
# TIMESTEP 11526 / EPISODE 10 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.817249e+00
# TIMESTEP 11572 / EPISODE 10 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.799726e+00
# TIMESTEP 11618 / EPISODE 10 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.775404e+00
# TIMESTEP 11664 / EPISODE 10 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.796342e+00
# TIMESTEP 11710 / EPISODE 10 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.808259e+00
# TIMESTEP 11756 / EPISODE 10 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.732641e+00
# TIMESTEP 11802 / EPISODE 10 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.804709e+00
# TIMESTEP 11848 / EPISODE 10 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.717866e+00
# TIMESTEP 11894 / EPISODE 10 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.772526e+00
# TIMESTEP 11940 / EPISODE 11 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.697994e+00
# TIMESTEP 11986 / EPISODE 11 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.655141e+00
# TIMESTEP 12032 / EPISODE 11 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.686355e+00
# TIMESTEP 12078 / EPISODE 11 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.652090e+00
# TIMESTEP 12124 / EPISODE 11 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.661057e+00
# TIMESTEP 12170 / EPISODE 11 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.669407e+00
# TIMESTEP 12216 / EPISODE 11 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.610946e+00
# TIMESTEP 12262 / EPISODE 11 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.645498e+00
# TIMESTEP 12308 / EPISODE 11 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.636673e+00
# TIMESTEP 12354 / EPISODE 11 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.645580e+00
# TIMESTEP 12400 / EPISODE 11 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.615616e+00
# TIMESTEP 12446 / EPISODE 11 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.597461e+00
# TIMESTEP 12492 / EPISODE 11 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.593589e+00
# TIMESTEP 12538 / EPISODE 11 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.569717e+00
# TIMESTEP 12584 / EPISODE 11 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.542674e+00
# TIMESTEP 12630 / EPISODE 11 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.425177e+00
# TIMESTEP 12846 / EPISODE 11 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.744679e+00
# TIMESTEP 12892 / EPISODE 11 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.726151e+00
# TIMESTEP 12938 / EPISODE 11 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.728486e+00
# TIMESTEP 12984 / EPISODE 11 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.716130e+00
# TIMESTEP 13030 / EPISODE 12 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.844798e+00
# TIMESTEP 13076 / EPISODE 12 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.766817e+00
# TIMESTEP 13122 / EPISODE 12 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.819553e+00
# TIMESTEP 13168 / EPISODE 12 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.845204e+00
# TIMESTEP 13214 / EPISODE 12 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.868959e+00
# TIMESTEP 13260 / EPISODE 12 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.821791e+00
# TIMESTEP 13306 / EPISODE 12 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.860517e+00
# TIMESTEP 13352 / EPISODE 12 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.845962e+00
# TIMESTEP 13398 / EPISODE 12 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.792084e+00
# TIMESTEP 13444 / EPISODE 12 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.830529e+00
# TIMESTEP 13490 / EPISODE 12 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.832169e+00
# TIMESTEP 13536 / EPISODE 12 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.791811e+00
# TIMESTEP 13582 / EPISODE 12 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.824288e+00
# TIMESTEP 13628 / EPISODE 12 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.784780e+00
# TIMESTEP 13674 / EPISODE 12 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.798174e+00
# TIMESTEP 13720 / EPISODE 12 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.791250e+00
# TIMESTEP 13766 / EPISODE 12 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.796154e+00
# TIMESTEP 13812 / EPISODE 12 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.746552e+00
# TIMESTEP 13858 / EPISODE 12 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.799885e+00
# TIMESTEP 13904 / EPISODE 12 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.720416e+00
# TIMESTEP 13950 / EPISODE 13 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.702235e+00
# TIMESTEP 13996 / EPISODE 13 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.761620e+00
# TIMESTEP 14042 / EPISODE 13 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.665508e+00
# TIMESTEP 14088 / EPISODE 13 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.747369e+00
# TIMESTEP 14134 / EPISODE 13 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.735644e+00
# TIMESTEP 14180 / EPISODE 13 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.673348e+00
# TIMESTEP 14226 / EPISODE 13 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.791875e+00
# TIMESTEP 14272 / EPISODE 13 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.674755e+00
# TIMESTEP 14318 / EPISODE 13 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.784593e+00
# TIMESTEP 14364 / EPISODE 13 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.679573e+00
# TIMESTEP 14410 / EPISODE 13 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.773180e+00
# TIMESTEP 14456 / EPISODE 13 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.747119e+00
# TIMESTEP 14502 / EPISODE 13 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.694298e+00
# TIMESTEP 14548 / EPISODE 13 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.752405e+00
# TIMESTEP 14594 / EPISODE 13 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.684252e+00
# TIMESTEP 14640 / EPISODE 13 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.731348e+00
# TIMESTEP 14686 / EPISODE 13 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.721743e+00
# TIMESTEP 14732 / EPISODE 13 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.752140e+00
# TIMESTEP 14778 / EPISODE 13 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.695087e+00
# TIMESTEP 14824 / EPISODE 13 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.716999e+00
# TIMESTEP 14870 / EPISODE 14 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.610820e+00
# TIMESTEP 14916 / EPISODE 14 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.671470e+00
# TIMESTEP 14962 / EPISODE 14 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.563046e+00
# TIMESTEP 15008 / EPISODE 14 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.609455e+00
# TIMESTEP 15054 / EPISODE 14 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.545499e+00
# TIMESTEP 15100 / EPISODE 14 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.476613e+00
# TIMESTEP 15146 / EPISODE 14 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.578867e+00
# TIMESTEP 15192 / EPISODE 14 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.485713e+00
# TIMESTEP 15238 / EPISODE 14 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.495866e+00
# TIMESTEP 15284 / EPISODE 14 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.617126e+00
# TIMESTEP 15330 / EPISODE 14 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.496685e+00
# TIMESTEP 15376 / EPISODE 14 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.626603e+00
# TIMESTEP 15422 / EPISODE 14 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.527752e+00
# TIMESTEP 15468 / EPISODE 14 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.657499e+00
# TIMESTEP 15514 / EPISODE 14 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.533453e+00
# TIMESTEP 15560 / EPISODE 14 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.589035e+00
# TIMESTEP 15606 / EPISODE 14 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.555172e+00
# TIMESTEP 15652 / EPISODE 14 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.674057e+00
# TIMESTEP 15698 / EPISODE 14 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.565949e+00
# TIMESTEP 15744 / EPISODE 14 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.675615e+00
# TIMESTEP 15790 / EPISODE 15 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.537946e+00
# TIMESTEP 15836 / EPISODE 15 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.661305e+00
# TIMESTEP 15882 / EPISODE 15 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.471793e+00
# TIMESTEP 15928 / EPISODE 15 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.635266e+00
# TIMESTEP 15974 / EPISODE 15 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.488634e+00
# TIMESTEP 16020 / EPISODE 15 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.633735e+00
# TIMESTEP 16066 / EPISODE 15 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.451155e+00
# TIMESTEP 16112 / EPISODE 15 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.636685e+00
# TIMESTEP 16158 / EPISODE 15 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.432209e+00
# TIMESTEP 16204 / EPISODE 15 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.618601e+00
# TIMESTEP 16250 / EPISODE 15 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.425573e+00
# TIMESTEP 16296 / EPISODE 15 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.614245e+00
# TIMESTEP 16342 / EPISODE 15 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.474572e+00
# TIMESTEP 16388 / EPISODE 15 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.644657e+00
# TIMESTEP 16434 / EPISODE 15 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.478425e+00
# TIMESTEP 16480 / EPISODE 15 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.619502e+00
# TIMESTEP 16526 / EPISODE 15 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.450002e+00
# TIMESTEP 16572 / EPISODE 15 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.575064e+00
# TIMESTEP 16618 / EPISODE 15 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.416600e+00
# TIMESTEP 16664 / EPISODE 15 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.572000e+00
# TIMESTEP 16710 / EPISODE 16 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 1.387192e+00
# TIMESTEP 16756 / EPISODE 16 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.570114e+00
# TIMESTEP 16802 / EPISODE 16 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.303549e+00
# TIMESTEP 16848 / EPISODE 16 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.491022e+00
# TIMESTEP 16894 / EPISODE 16 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.216048e+00
# TIMESTEP 16940 / EPISODE 16 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.381254e+00
# TIMESTEP 16986 / EPISODE 16 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.150133e+00
# TIMESTEP 17032 / EPISODE 16 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.314732e+00
# TIMESTEP 17078 / EPISODE 16 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.111581e+00
# TIMESTEP 17124 / EPISODE 16 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.292048e+00
# TIMESTEP 17170 / EPISODE 16 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.023459e+00
# TIMESTEP 17216 / EPISODE 16 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.023672e+00
# TIMESTEP 17262 / EPISODE 16 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 9.856385e-01
# TIMESTEP 17308 / EPISODE 16 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.225667e+00
# TIMESTEP 17354 / EPISODE 16 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.063692e+00
# TIMESTEP 17400 / EPISODE 16 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.258705e+00
# TIMESTEP 17446 / EPISODE 16 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 1.066091e+00
# TIMESTEP 17492 / EPISODE 16 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.211011e+00
# TIMESTEP 17538 / EPISODE 16 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 1.015584e+00
# TIMESTEP 17584 / EPISODE 16 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.124482e+00
# TIMESTEP 17630 / EPISODE 17 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 9.352996e-01
# TIMESTEP 17676 / EPISODE 17 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.223392e+00
# TIMESTEP 17722 / EPISODE 17 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 9.010188e-01
# TIMESTEP 17768 / EPISODE 17 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 1.187501e+00
# TIMESTEP 17814 / EPISODE 17 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 8.145502e-01
# TIMESTEP 17860 / EPISODE 17 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 9.587973e-01
# TIMESTEP 18073 / EPISODE 17 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 8.720189e-01
# TIMESTEP 18119 / EPISODE 17 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 7.889675e-01
# TIMESTEP 18165 / EPISODE 17 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 5.548079e-01
# TIMESTEP 18211 / EPISODE 17 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 8.525998e-01
# TIMESTEP 18257 / EPISODE 17 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 6.412807e-01
# TIMESTEP 18303 / EPISODE 17 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 6.696932e-01
# TIMESTEP 18349 / EPISODE 17 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 5.839122e-01
# TIMESTEP 18395 / EPISODE 17 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 7.760417e-01
# TIMESTEP 18441 / EPISODE 17 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 5.685169e-01
# TIMESTEP 18487 / EPISODE 17 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 6.282928e-01
# TIMESTEP 18533 / EPISODE 17 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 5.513774e-01
# TIMESTEP 18579 / EPISODE 17 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 5.926096e-01
# TIMESTEP 18625 / EPISODE 17 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 6.602718e-01
# TIMESTEP 18671 / EPISODE 17 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 9.252761e-01
# TIMESTEP 18717 / EPISODE 18 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 7.562318e-01
# TIMESTEP 18763 / EPISODE 18 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.022988e+00
# TIMESTEP 18809 / EPISODE 18 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 7.956601e-01
# TIMESTEP 18855 / EPISODE 18 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 9.642301e-01
# TIMESTEP 18901 / EPISODE 18 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 6.317900e-01
# TIMESTEP 18947 / EPISODE 18 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 7.259265e-01
# TIMESTEP 18993 / EPISODE 18 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 5.988713e-01
# TIMESTEP 19039 / EPISODE 18 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 6.056297e-01
# TIMESTEP 19085 / EPISODE 18 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 5.005429e-01
# TIMESTEP 19131 / EPISODE 18 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 7.166536e-01
# TIMESTEP 19177 / EPISODE 18 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 3.896469e-01
# TIMESTEP 19223 / EPISODE 18 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 6.711572e-01
# TIMESTEP 19269 / EPISODE 18 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 4.659295e-01
# TIMESTEP 19398 / EPISODE 18 / bar1_score 1 / bar2_score 12 / REWARD 1 / Q_MAX 8.893536e-01
# TIMESTEP 19527 / EPISODE 18 / bar1_score 1 / bar2_score 13 / REWARD -1 / Q_MAX 2.957919e-01
# TIMESTEP 19658 / EPISODE 18 / bar1_score 2 / bar2_score 13 / REWARD 1 / Q_MAX 1.095970e+00
# TIMESTEP 19787 / EPISODE 18 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 2.088231e-01
# TIMESTEP 19833 / EPISODE 18 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 4.394694e-01
# TIMESTEP 19879 / EPISODE 18 / bar1_score 2 / bar2_score 16 / REWARD -1 / Q_MAX 2.468509e-01
# TIMESTEP 19925 / EPISODE 18 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 6.400195e-01
# TIMESTEP 19971 / EPISODE 18 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 4.113655e-01
# TIMESTEP 20017 / EPISODE 18 / bar1_score 2 / bar2_score 19 / REWARD -1 / Q_MAX 7.535246e-01
# TIMESTEP 20063 / EPISODE 19 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 4.100212e-01
# TIMESTEP 20192 / EPISODE 19 / bar1_score 1 / bar2_score 0 / REWARD 1 / Q_MAX 7.521243e-01
# TIMESTEP 20321 / EPISODE 19 / bar1_score 1 / bar2_score 1 / REWARD -1 / Q_MAX 3.060632e-01
# TIMESTEP 20367 / EPISODE 19 / bar1_score 1 / bar2_score 2 / REWARD -1 / Q_MAX 7.468851e-01
# TIMESTEP 20413 / EPISODE 19 / bar1_score 1 / bar2_score 3 / REWARD -1 / Q_MAX 4.868965e-01
# TIMESTEP 20542 / EPISODE 19 / bar1_score 2 / bar2_score 3 / REWARD 1 / Q_MAX 1.533771e+00
# TIMESTEP 20924 / EPISODE 19 / bar1_score 3 / bar2_score 3 / REWARD 1 / Q_MAX 7.471943e-01
# TIMESTEP 21053 / EPISODE 19 / bar1_score 3 / bar2_score 4 / REWARD -1 / Q_MAX 3.732054e-01
# TIMESTEP 21099 / EPISODE 19 / bar1_score 3 / bar2_score 5 / REWARD -1 / Q_MAX 3.350912e-01
# TIMESTEP 21145 / EPISODE 19 / bar1_score 3 / bar2_score 6 / REWARD -1 / Q_MAX 2.341134e-01
# TIMESTEP 21191 / EPISODE 19 / bar1_score 3 / bar2_score 7 / REWARD -1 / Q_MAX 3.319633e-01
# TIMESTEP 21237 / EPISODE 19 / bar1_score 3 / bar2_score 8 / REWARD -1 / Q_MAX 2.438989e-01
# TIMESTEP 21283 / EPISODE 19 / bar1_score 3 / bar2_score 9 / REWARD -1 / Q_MAX 6.749721e-01
# TIMESTEP 21329 / EPISODE 19 / bar1_score 3 / bar2_score 10 / REWARD -1 / Q_MAX 4.456424e-01
# TIMESTEP 21375 / EPISODE 19 / bar1_score 3 / bar2_score 11 / REWARD -1 / Q_MAX 8.344290e-01
# TIMESTEP 21421 / EPISODE 19 / bar1_score 3 / bar2_score 12 / REWARD -1 / Q_MAX 5.980490e-01
# TIMESTEP 21467 / EPISODE 19 / bar1_score 3 / bar2_score 13 / REWARD -1 / Q_MAX 1.099025e+00
# TIMESTEP 21682 / EPISODE 19 / bar1_score 3 / bar2_score 14 / REWARD -1 / Q_MAX 1.476284e+00
# TIMESTEP 21728 / EPISODE 19 / bar1_score 3 / bar2_score 15 / REWARD -1 / Q_MAX 1.083092e+00
# TIMESTEP 21774 / EPISODE 19 / bar1_score 3 / bar2_score 16 / REWARD -1 / Q_MAX 6.539344e-01
# TIMESTEP 21820 / EPISODE 19 / bar1_score 3 / bar2_score 17 / REWARD -1 / Q_MAX 8.911594e-01
# TIMESTEP 21866 / EPISODE 19 / bar1_score 3 / bar2_score 18 / REWARD -1 / Q_MAX 6.786156e-01
# TIMESTEP 21912 / EPISODE 19 / bar1_score 3 / bar2_score 19 / REWARD -1 / Q_MAX 1.106133e+00
# TIMESTEP 21958 / EPISODE 20 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 6.961101e-01
# TIMESTEP 22004 / EPISODE 20 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 1.005371e+00
# TIMESTEP 22050 / EPISODE 20 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 6.275808e-01
# TIMESTEP 22096 / EPISODE 20 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 8.790254e-01
# TIMESTEP 22142 / EPISODE 20 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 4.758443e-01
# TIMESTEP 22188 / EPISODE 20 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 5.469449e-01
# TIMESTEP 22234 / EPISODE 20 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 3.766968e-01
# TIMESTEP 22280 / EPISODE 20 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 5.293301e-01
# TIMESTEP 22326 / EPISODE 20 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 2.506520e-01
# TIMESTEP 22372 / EPISODE 20 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 3.781056e-01
# TIMESTEP 22418 / EPISODE 20 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 1.960389e-01
# TIMESTEP 22464 / EPISODE 20 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 3.041967e-01
# TIMESTEP 22510 / EPISODE 20 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 1.568187e-01
# TIMESTEP 22556 / EPISODE 20 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.296198e-01
# TIMESTEP 22602 / EPISODE 20 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.787544e-01
# TIMESTEP 22648 / EPISODE 20 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 2.947931e-01
# TIMESTEP 22694 / EPISODE 20 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 2.474695e-01
# TIMESTEP 22823 / EPISODE 20 / bar1_score 1 / bar2_score 16 / REWARD 1 / Q_MAX 7.354833e-01
# TIMESTEP 22952 / EPISODE 20 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX 2.347415e-01
# TIMESTEP 22998 / EPISODE 20 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX 5.949811e-01
# TIMESTEP 23044 / EPISODE 20 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX 4.507571e-01
# TIMESTEP 23090 / EPISODE 21 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 5.979407e-01
# TIMESTEP 23136 / EPISODE 21 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 9.719505e-02
# TIMESTEP 23182 / EPISODE 21 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.818433e-01
# TIMESTEP 23228 / EPISODE 21 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 2.054310e-01
# TIMESTEP 23274 / EPISODE 21 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.656169e-01
# TIMESTEP 23320 / EPISODE 21 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.052394e-01
# TIMESTEP 23366 / EPISODE 21 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.399748e-01
# TIMESTEP 23412 / EPISODE 21 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 6.565291e-02
# TIMESTEP 23458 / EPISODE 21 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 1.499607e-01
# TIMESTEP 23504 / EPISODE 21 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 8.641242e-02
# TIMESTEP 23550 / EPISODE 21 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 2.324849e-01
# TIMESTEP 23596 / EPISODE 21 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 2.208054e-01
# TIMESTEP 23642 / EPISODE 21 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 2.750366e-01
# TIMESTEP 23688 / EPISODE 21 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.825485e-01
# TIMESTEP 23734 / EPISODE 21 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 2.305417e-01
# TIMESTEP 23780 / EPISODE 21 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 1.166917e-01
# TIMESTEP 23826 / EPISODE 21 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 2.772219e-01
# TIMESTEP 23872 / EPISODE 21 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 7.423265e-02
# TIMESTEP 23918 / EPISODE 21 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 2.620301e-01
# TIMESTEP 23964 / EPISODE 21 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX 1.275386e-01
# TIMESTEP 24010 / EPISODE 22 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 2.442814e-01
# TIMESTEP 24224 / EPISODE 22 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 6.632065e-01
# TIMESTEP 24270 / EPISODE 22 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 1.425951e-01
# TIMESTEP 24316 / EPISODE 22 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 5.679614e-02
# TIMESTEP 24362 / EPISODE 22 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 1.453021e-01
# TIMESTEP 24408 / EPISODE 22 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 6.156236e-02
# TIMESTEP 24454 / EPISODE 22 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 1.006253e-01
# TIMESTEP 24500 / EPISODE 22 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 4.259358e-02
# TIMESTEP 24629 / EPISODE 22 / bar1_score 1 / bar2_score 7 / REWARD 1 / Q_MAX 3.560825e-01
# TIMESTEP 25010 / EPISODE 22 / bar1_score 2 / bar2_score 7 / REWARD 1 / Q_MAX 1.284367e+00
# TIMESTEP 25139 / EPISODE 22 / bar1_score 2 / bar2_score 8 / REWARD -1 / Q_MAX 3.506041e-01
# TIMESTEP 25185 / EPISODE 22 / bar1_score 2 / bar2_score 9 / REWARD -1 / Q_MAX 1.555950e-01
# TIMESTEP 25231 / EPISODE 22 / bar1_score 2 / bar2_score 10 / REWARD -1 / Q_MAX 9.604405e-02
# TIMESTEP 25277 / EPISODE 22 / bar1_score 2 / bar2_score 11 / REWARD -1 / Q_MAX 4.012000e-02
# TIMESTEP 25493 / EPISODE 22 / bar1_score 2 / bar2_score 12 / REWARD -1 / Q_MAX 1.258624e-01
# TIMESTEP 25539 / EPISODE 22 / bar1_score 2 / bar2_score 13 / REWARD -1 / Q_MAX -2.519356e-03
# TIMESTEP 25585 / EPISODE 22 / bar1_score 2 / bar2_score 14 / REWARD -1 / Q_MAX 1.307270e-02
# TIMESTEP 25631 / EPISODE 22 / bar1_score 2 / bar2_score 15 / REWARD -1 / Q_MAX 2.623367e-02
# TIMESTEP 25677 / EPISODE 22 / bar1_score 2 / bar2_score 16 / REWARD -1 / Q_MAX 1.921254e-02
# TIMESTEP 25723 / EPISODE 22 / bar1_score 2 / bar2_score 17 / REWARD -1 / Q_MAX 5.055770e-02
# TIMESTEP 25769 / EPISODE 22 / bar1_score 2 / bar2_score 18 / REWARD -1 / Q_MAX 2.913223e-02
# TIMESTEP 25815 / EPISODE 22 / bar1_score 2 / bar2_score 19 / REWARD -1 / Q_MAX 4.252130e-02
# TIMESTEP 25861 / EPISODE 23 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 4.784339e-02
# TIMESTEP 25907 / EPISODE 23 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 6.818475e-02
# TIMESTEP 26120 / EPISODE 23 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 5.718167e-01
# TIMESTEP 26166 / EPISODE 23 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX 3.716447e-02
# TIMESTEP 26212 / EPISODE 23 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 5.430222e-02
# TIMESTEP 26258 / EPISODE 23 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 7.221489e-02
# TIMESTEP 26304 / EPISODE 23 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 7.439115e-02
# TIMESTEP 26350 / EPISODE 23 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 3.562305e-02
# TIMESTEP 26396 / EPISODE 23 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 7.386302e-02
# TIMESTEP 26442 / EPISODE 23 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 1.342421e-01
# TIMESTEP 26488 / EPISODE 23 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 9.332384e-02
# TIMESTEP 26534 / EPISODE 23 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.434424e-01
# TIMESTEP 26580 / EPISODE 23 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 7.213634e-02
# TIMESTEP 26626 / EPISODE 23 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.728989e-01
# TIMESTEP 26672 / EPISODE 23 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 2.434073e-01
# TIMESTEP 26718 / EPISODE 23 / bar1_score 0 / bar2_score 15 / REWARD -1 / Q_MAX 3.190267e-01
# TIMESTEP 26933 / EPISODE 23 / bar1_score 0 / bar2_score 16 / REWARD -1 / Q_MAX 8.219191e-01
# TIMESTEP 26979 / EPISODE 23 / bar1_score 0 / bar2_score 17 / REWARD -1 / Q_MAX 1.736584e-01
# TIMESTEP 27025 / EPISODE 23 / bar1_score 0 / bar2_score 18 / REWARD -1 / Q_MAX 3.857277e-02
# TIMESTEP 27071 / EPISODE 23 / bar1_score 0 / bar2_score 19 / REWARD -1 / Q_MAX -4.084471e-03
# TIMESTEP 27117 / EPISODE 24 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -1.203800e-02
# TIMESTEP 27163 / EPISODE 24 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -4.290219e-02
# TIMESTEP 27209 / EPISODE 24 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX -3.508562e-02
# TIMESTEP 27255 / EPISODE 24 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -2.332357e-03
# TIMESTEP 27301 / EPISODE 24 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX 2.742326e-03
# TIMESTEP 27347 / EPISODE 24 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 1.149066e-01
# TIMESTEP 27393 / EPISODE 24 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX 9.976310e-02
# TIMESTEP 27439 / EPISODE 24 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX 1.744729e-01
# TIMESTEP 27485 / EPISODE 24 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 2.178663e-01
# TIMESTEP 27531 / EPISODE 24 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 2.441660e-01
# TIMESTEP 27577 / EPISODE 24 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 2.347906e-01
# TIMESTEP 27706 / EPISODE 24 / bar1_score 1 / bar2_score 10 / REWARD 1 / Q_MAX 1.100317e+00
# TIMESTEP 27835 / EPISODE 24 / bar1_score 1 / bar2_score 11 / REWARD -1 / Q_MAX 1.031798e-01
# TIMESTEP 27881 / EPISODE 24 / bar1_score 1 / bar2_score 12 / REWARD -1 / Q_MAX 5.036181e-01
# TIMESTEP 27927 / EPISODE 24 / bar1_score 1 / bar2_score 13 / REWARD -1 / Q_MAX 3.396693e-01
# TIMESTEP 27973 / EPISODE 24 / bar1_score 1 / bar2_score 14 / REWARD -1 / Q_MAX 4.927272e-01
# TIMESTEP 28019 / EPISODE 24 / bar1_score 1 / bar2_score 15 / REWARD -1 / Q_MAX 3.472656e-01
# TIMESTEP 28065 / EPISODE 24 / bar1_score 1 / bar2_score 16 / REWARD -1 / Q_MAX 5.146317e-01
# TIMESTEP 28111 / EPISODE 24 / bar1_score 1 / bar2_score 17 / REWARD -1 / Q_MAX 4.283882e-01
# TIMESTEP 28157 / EPISODE 24 / bar1_score 1 / bar2_score 18 / REWARD -1 / Q_MAX 5.921250e-01
# TIMESTEP 28203 / EPISODE 24 / bar1_score 1 / bar2_score 19 / REWARD -1 / Q_MAX 5.764207e-01
# TIMESTEP 28332 / EPISODE 24 / bar1_score 2 / bar2_score 19 / REWARD 1 / Q_MAX 1.329349e+00
# TIMESTEP 28461 / EPISODE 25 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 5.178094e-02
# TIMESTEP 28507 / EPISODE 25 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX -2.214745e-02
# TIMESTEP 28553 / EPISODE 25 / bar1_score 0 / bar2_score 2 / REWARD -1 / Q_MAX 2.083858e-02
# TIMESTEP 28599 / EPISODE 25 / bar1_score 0 / bar2_score 3 / REWARD -1 / Q_MAX -1.152585e-02
# TIMESTEP 28645 / EPISODE 25 / bar1_score 0 / bar2_score 4 / REWARD -1 / Q_MAX -9.836314e-03
# TIMESTEP 28691 / EPISODE 25 / bar1_score 0 / bar2_score 5 / REWARD -1 / Q_MAX 3.693837e-03
# TIMESTEP 28737 / EPISODE 25 / bar1_score 0 / bar2_score 6 / REWARD -1 / Q_MAX -2.155201e-02
# TIMESTEP 28783 / EPISODE 25 / bar1_score 0 / bar2_score 7 / REWARD -1 / Q_MAX -4.479254e-02
# TIMESTEP 28829 / EPISODE 25 / bar1_score 0 / bar2_score 8 / REWARD -1 / Q_MAX 5.340646e-02
# TIMESTEP 28875 / EPISODE 25 / bar1_score 0 / bar2_score 9 / REWARD -1 / Q_MAX 2.573858e-02
# TIMESTEP 28921 / EPISODE 25 / bar1_score 0 / bar2_score 10 / REWARD -1 / Q_MAX 2.099144e-01
# TIMESTEP 28967 / EPISODE 25 / bar1_score 0 / bar2_score 11 / REWARD -1 / Q_MAX 1.123187e-01
# TIMESTEP 29013 / EPISODE 25 / bar1_score 0 / bar2_score 12 / REWARD -1 / Q_MAX 2.259223e-01
# TIMESTEP 29059 / EPISODE 25 / bar1_score 0 / bar2_score 13 / REWARD -1 / Q_MAX 1.122184e-01
# TIMESTEP 29105 / EPISODE 25 / bar1_score 0 / bar2_score 14 / REWARD -1 / Q_MAX 1.661676e-01
# ...
# TIMESTEP 190267 / EPISODE 90 / bar1_score 9 / bar2_score 14 / REWARD -1 / Q_MAX 5.270506e-01
# TIMESTEP 190396 / EPISODE 90 / bar1_score 10 / bar2_score 14 / REWARD 1 / Q_MAX 2.786563e+00
# TIMESTEP 190777 / EPISODE 90 / bar1_score 11 / bar2_score 14 / REWARD 1 / Q_MAX 2.709008e+00
# TIMESTEP 190906 / EPISODE 90 / bar1_score 11 / bar2_score 15 / REWARD -1 / Q_MAX 5.257683e-01
# TIMESTEP 191035 / EPISODE 90 / bar1_score 12 / bar2_score 15 / REWARD 1 / Q_MAX 2.908283e+00
# TIMESTEP 191164 / EPISODE 90 / bar1_score 12 / bar2_score 16 / REWARD -1 / Q_MAX 7.885819e-01
# TIMESTEP 191295 / EPISODE 90 / bar1_score 13 / bar2_score 16 / REWARD 1 / Q_MAX 2.789431e+00
# TIMESTEP 191424 / EPISODE 90 / bar1_score 13 / bar2_score 17 / REWARD -1 / Q_MAX 3.882473e-01
# TIMESTEP 191553 / EPISODE 90 / bar1_score 14 / bar2_score 17 / REWARD 1 / Q_MAX 2.749007e+00
# TIMESTEP 191934 / EPISODE 90 / bar1_score 15 / bar2_score 17 / REWARD 1 / Q_MAX 2.704824e+00
# TIMESTEP 192232 / EPISODE 90 / bar1_score 15 / bar2_score 18 / REWARD -1 / Q_MAX 1.362528e+00
# TIMESTEP 192448 / EPISODE 90 / bar1_score 15 / bar2_score 19 / REWARD -1 / Q_MAX 5.228311e-01
# TIMESTEP 192577 / EPISODE 90 / bar1_score 16 / bar2_score 19 / REWARD 1 / Q_MAX 2.264297e+00
# TIMESTEP 192706 / EPISODE 91 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -8.010115e-03
# TIMESTEP 192835 / EPISODE 91 / bar1_score 1 / bar2_score 0 / REWARD 1 / Q_MAX 2.693091e+00
# TIMESTEP 192964 / EPISODE 91 / bar1_score 1 / bar2_score 1 / REWARD -1 / Q_MAX 7.361068e-01
# TIMESTEP 193093 / EPISODE 91 / bar1_score 2 / bar2_score 1 / REWARD 1 / Q_MAX 3.044212e+00
# TIMESTEP 193391 / EPISODE 91 / bar1_score 2 / bar2_score 2 / REWARD -1 / Q_MAX 2.440518e+00
# TIMESTEP 193437 / EPISODE 91 / bar1_score 2 / bar2_score 3 / REWARD -1 / Q_MAX 1.184440e+00
# TIMESTEP 193483 / EPISODE 91 / bar1_score 2 / bar2_score 4 / REWARD -1 / Q_MAX 1.056966e+00
# TIMESTEP 193781 / EPISODE 91 / bar1_score 3 / bar2_score 4 / REWARD 1 / Q_MAX 2.763153e+00
# TIMESTEP 193910 / EPISODE 91 / bar1_score 3 / bar2_score 5 / REWARD -1 / Q_MAX 1.242648e+00
# TIMESTEP 193956 / EPISODE 91 / bar1_score 3 / bar2_score 6 / REWARD -1 / Q_MAX 9.632182e-01
# TIMESTEP 194253 / EPISODE 91 / bar1_score 4 / bar2_score 6 / REWARD 1 / Q_MAX 2.944430e+00
# TIMESTEP 194382 / EPISODE 91 / bar1_score 4 / bar2_score 7 / REWARD -1 / Q_MAX 1.109718e+00
# TIMESTEP 194513 / EPISODE 91 / bar1_score 5 / bar2_score 7 / REWARD 1 / Q_MAX 2.978096e+00
# TIMESTEP 194894 / EPISODE 91 / bar1_score 6 / bar2_score 7 / REWARD 1 / Q_MAX 3.066833e+00
# TIMESTEP 195023 / EPISODE 91 / bar1_score 6 / bar2_score 8 / REWARD -1 / Q_MAX 1.037857e+00
# TIMESTEP 195152 / EPISODE 91 / bar1_score 7 / bar2_score 8 / REWARD 1 / Q_MAX 3.016423e+00
# TIMESTEP 195281 / EPISODE 91 / bar1_score 7 / bar2_score 9 / REWARD -1 / Q_MAX 1.070996e+00
# TIMESTEP 195410 / EPISODE 91 / bar1_score 8 / bar2_score 9 / REWARD 1 / Q_MAX 2.863810e+00
# TIMESTEP 195539 / EPISODE 91 / bar1_score 8 / bar2_score 10 / REWARD -1 / Q_MAX 2.807045e-01
# TIMESTEP 195670 / EPISODE 91 / bar1_score 9 / bar2_score 10 / REWARD 1 / Q_MAX 2.771347e+00
# TIMESTEP 195799 / EPISODE 91 / bar1_score 9 / bar2_score 11 / REWARD -1 / Q_MAX 7.266958e-01
# TIMESTEP 195928 / EPISODE 91 / bar1_score 10 / bar2_score 11 / REWARD 1 / Q_MAX 2.886946e+00
# TIMESTEP 196057 / EPISODE 91 / bar1_score 10 / bar2_score 12 / REWARD -1 / Q_MAX 8.064457e-01
# TIMESTEP 196186 / EPISODE 91 / bar1_score 11 / bar2_score 12 / REWARD 1 / Q_MAX 3.025148e+00
# TIMESTEP 196315 / EPISODE 91 / bar1_score 11 / bar2_score 13 / REWARD -1 / Q_MAX 8.169472e-01
# TIMESTEP 196361 / EPISODE 91 / bar1_score 11 / bar2_score 14 / REWARD -1 / Q_MAX 4.774415e-01
# TIMESTEP 196659 / EPISODE 91 / bar1_score 12 / bar2_score 14 / REWARD 1 / Q_MAX 2.814571e+00
# TIMESTEP 196956 / EPISODE 91 / bar1_score 12 / bar2_score 15 / REWARD -1 / Q_MAX 9.875287e-01
# TIMESTEP 197002 / EPISODE 91 / bar1_score 12 / bar2_score 16 / REWARD -1 / Q_MAX 1.373685e+00
# TIMESTEP 197131 / EPISODE 91 / bar1_score 13 / bar2_score 16 / REWARD 1 / Q_MAX 2.979319e+00
# TIMESTEP 197260 / EPISODE 91 / bar1_score 13 / bar2_score 17 / REWARD -1 / Q_MAX 3.094569e-01
# TIMESTEP 197306 / EPISODE 91 / bar1_score 13 / bar2_score 18 / REWARD -1 / Q_MAX 5.874088e-01
# TIMESTEP 197352 / EPISODE 91 / bar1_score 13 / bar2_score 19 / REWARD -1 / Q_MAX 1.145990e+00
# TIMESTEP 197398 / EPISODE 92 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX -1.873693e-01
# TIMESTEP 197696 / EPISODE 92 / bar1_score 1 / bar2_score 0 / REWARD 1 / Q_MAX 2.713562e+00
# TIMESTEP 197825 / EPISODE 92 / bar1_score 1 / bar2_score 1 / REWARD -1 / Q_MAX 6.419781e-01
# TIMESTEP 197871 / EPISODE 92 / bar1_score 1 / bar2_score 2 / REWARD -1 / Q_MAX 4.189843e-01
# TIMESTEP 197917 / EPISODE 92 / bar1_score 1 / bar2_score 3 / REWARD -1 / Q_MAX 7.766455e-01
# TIMESTEP 198047 / EPISODE 92 / bar1_score 2 / bar2_score 3 / REWARD 1 / Q_MAX 2.951605e+00
# TIMESTEP 198176 / EPISODE 92 / bar1_score 2 / bar2_score 4 / REWARD -1 / Q_MAX 8.075739e-01
# TIMESTEP 198307 / EPISODE 92 / bar1_score 3 / bar2_score 4 / REWARD 1 / Q_MAX 2.802801e+00
# TIMESTEP 198436 / EPISODE 92 / bar1_score 3 / bar2_score 5 / REWARD -1 / Q_MAX 1.148627e+00
# TIMESTEP 198565 / EPISODE 92 / bar1_score 4 / bar2_score 5 / REWARD 1 / Q_MAX 2.957095e+00
# TIMESTEP 198694 / EPISODE 92 / bar1_score 4 / bar2_score 6 / REWARD -1 / Q_MAX 6.669503e-01
# TIMESTEP 198823 / EPISODE 92 / bar1_score 5 / bar2_score 6 / REWARD 1 / Q_MAX 2.658559e+00
# TIMESTEP 198952 / EPISODE 92 / bar1_score 5 / bar2_score 7 / REWARD -1 / Q_MAX 8.644460e-01
# TIMESTEP 199081 / EPISODE 92 / bar1_score 6 / bar2_score 7 / REWARD 1 / Q_MAX 2.751424e+00
# TIMESTEP 199464 / EPISODE 92 / bar1_score 7 / bar2_score 7 / REWARD 1 / Q_MAX 2.625890e+00
# TIMESTEP 199848 / EPISODE 92 / bar1_score 8 / bar2_score 7 / REWARD 1 / Q_MAX 2.569200e+00
# TIMESTEP 199977 / EPISODE 92 / bar1_score 8 / bar2_score 8 / REWARD -1 / Q_MAX 7.307959e-01
# TIMESTEP 200106 / EPISODE 92 / bar1_score 9 / bar2_score 8 / REWARD 1 / Q_MAX 2.825596e+00
# TIMESTEP 200489 / EPISODE 92 / bar1_score 10 / bar2_score 8 / REWARD 1 / Q_MAX 2.800809e+00
# TIMESTEP 200618 / EPISODE 92 / bar1_score 10 / bar2_score 9 / REWARD -1 / Q_MAX 8.647596e-01
# TIMESTEP 200749 / EPISODE 92 / bar1_score 11 / bar2_score 9 / REWARD 1 / Q_MAX 2.676986e+00
# TIMESTEP 200878 / EPISODE 92 / bar1_score 11 / bar2_score 10 / REWARD -1 / Q_MAX 4.296064e-01
# TIMESTEP 201009 / EPISODE 92 / bar1_score 12 / bar2_score 10 / REWARD 1 / Q_MAX 2.502644e+00
# TIMESTEP 201390 / EPISODE 92 / bar1_score 13 / bar2_score 10 / REWARD 1 / Q_MAX 2.998552e+00
# TIMESTEP 201519 / EPISODE 92 / bar1_score 13 / bar2_score 11 / REWARD -1 / Q_MAX 1.026330e+00
# TIMESTEP 201565 / EPISODE 92 / bar1_score 13 / bar2_score 12 / REWARD -1 / Q_MAX 1.034926e+00
# TIMESTEP 201780 / EPISODE 92 / bar1_score 13 / bar2_score 13 / REWARD -1 / Q_MAX 2.339863e+00
# TIMESTEP 201909 / EPISODE 92 / bar1_score 14 / bar2_score 13 / REWARD 1 / Q_MAX 3.142345e+00
# TIMESTEP 202038 / EPISODE 92 / bar1_score 14 / bar2_score 14 / REWARD -1 / Q_MAX 1.611583e+00
# TIMESTEP 202167 / EPISODE 92 / bar1_score 15 / bar2_score 14 / REWARD 1 / Q_MAX 3.017639e+00
# TIMESTEP 202296 / EPISODE 92 / bar1_score 15 / bar2_score 15 / REWARD -1 / Q_MAX 1.109553e+00
# TIMESTEP 202425 / EPISODE 92 / bar1_score 16 / bar2_score 15 / REWARD 1 / Q_MAX 2.907116e+00
# TIMESTEP 202722 / EPISODE 92 / bar1_score 16 / bar2_score 16 / REWARD -1 / Q_MAX 8.275564e-01
# TIMESTEP 202935 / EPISODE 92 / bar1_score 16 / bar2_score 17 / REWARD -1 / Q_MAX 6.682723e-01
# TIMESTEP 203064 / EPISODE 92 / bar1_score 17 / bar2_score 17 / REWARD 1 / Q_MAX 2.555168e+00
# TIMESTEP 203193 / EPISODE 92 / bar1_score 17 / bar2_score 18 / REWARD -1 / Q_MAX 8.178871e-01
# TIMESTEP 203322 / EPISODE 92 / bar1_score 18 / bar2_score 18 / REWARD 1 / Q_MAX 2.768727e+00
# TIMESTEP 203451 / EPISODE 92 / bar1_score 18 / bar2_score 19 / REWARD -1 / Q_MAX 6.965458e-01
# TIMESTEP 203580 / EPISODE 92 / bar1_score 19 / bar2_score 19 / REWARD 1 / Q_MAX 2.628640e+00
# TIMESTEP 203709 / EPISODE 93 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 2.143993e-01
# TIMESTEP 203838 / EPISODE 93 / bar1_score 1 / bar2_score 0 / REWARD 1 / Q_MAX 2.589553e+00
# TIMESTEP 203967 / EPISODE 93 / bar1_score 1 / bar2_score 1 / REWARD -1 / Q_MAX 8.249105e-01
# TIMESTEP 204098 / EPISODE 93 / bar1_score 2 / bar2_score 1 / REWARD 1 / Q_MAX 2.692928e+00
# TIMESTEP 204227 / EPISODE 93 / bar1_score 2 / bar2_score 2 / REWARD -1 / Q_MAX 6.743733e-01
# TIMESTEP 204356 / EPISODE 93 / bar1_score 3 / bar2_score 2 / REWARD 1 / Q_MAX 2.739064e+00
# TIMESTEP 204485 / EPISODE 93 / bar1_score 3 / bar2_score 3 / REWARD -1 / Q_MAX 7.647310e-01
# TIMESTEP 204531 / EPISODE 93 / bar1_score 3 / bar2_score 4 / REWARD -1 / Q_MAX 5.695748e-01
# TIMESTEP 204577 / EPISODE 93 / bar1_score 3 / bar2_score 5 / REWARD -1 / Q_MAX 6.426992e-01
# TIMESTEP 204706 / EPISODE 93 / bar1_score 4 / bar2_score 5 / REWARD 1 / Q_MAX 2.540017e+00
# TIMESTEP 204835 / EPISODE 93 / bar1_score 4 / bar2_score 6 / REWARD -1 / Q_MAX 1.400559e+00
# TIMESTEP 204881 / EPISODE 93 / bar1_score 4 / bar2_score 7 / REWARD -1 / Q_MAX 5.996598e-01
# TIMESTEP 204927 / EPISODE 93 / bar1_score 4 / bar2_score 8 / REWARD -1 / Q_MAX 5.765226e-01
# TIMESTEP 205056 / EPISODE 93 / bar1_score 5 / bar2_score 8 / REWARD 1 / Q_MAX 2.636328e+00
# TIMESTEP 205437 / EPISODE 93 / bar1_score 6 / bar2_score 8 / REWARD 1 / Q_MAX 2.687069e+00
# TIMESTEP 205566 / EPISODE 93 / bar1_score 6 / bar2_score 9 / REWARD -1 / Q_MAX 8.820038e-01
# TIMESTEP 205695 / EPISODE 93 / bar1_score 7 / bar2_score 9 / REWARD 1 / Q_MAX 2.982469e+00
# TIMESTEP 205824 / EPISODE 93 / bar1_score 7 / bar2_score 10 / REWARD -1 / Q_MAX 1.230692e+00
# TIMESTEP 205870 / EPISODE 93 / bar1_score 7 / bar2_score 11 / REWARD -1 / Q_MAX 1.640059e+00
# TIMESTEP 206170 / EPISODE 93 / bar1_score 8 / bar2_score 11 / REWARD 1 / Q_MAX 2.702915e+00
# TIMESTEP 206299 / EPISODE 93 / bar1_score 8 / bar2_score 12 / REWARD -1 / Q_MAX 1.175141e+00
# TIMESTEP 206428 / EPISODE 93 / bar1_score 9 / bar2_score 12 / REWARD 1 / Q_MAX 2.887651e+00
# TIMESTEP 206809 / EPISODE 93 / bar1_score 10 / bar2_score 12 / REWARD 1 / Q_MAX 2.755260e+00
# TIMESTEP 206938 / EPISODE 93 / bar1_score 10 / bar2_score 13 / REWARD -1 / Q_MAX 2.455102e-01
# TIMESTEP 207067 / EPISODE 93 / bar1_score 11 / bar2_score 13 / REWARD 1 / Q_MAX 2.379703e+00
# TIMESTEP 207196 / EPISODE 93 / bar1_score 11 / bar2_score 14 / REWARD -1 / Q_MAX 9.311689e-02
# TIMESTEP 207325 / EPISODE 93 / bar1_score 12 / bar2_score 14 / REWARD 1 / Q_MAX 2.524928e+00
# TIMESTEP 207454 / EPISODE 93 / bar1_score 12 / bar2_score 15 / REWARD -1 / Q_MAX 4.841261e-01
# TIMESTEP 207583 / EPISODE 93 / bar1_score 13 / bar2_score 15 / REWARD 1 / Q_MAX 2.601981e+00
# TIMESTEP 207712 / EPISODE 93 / bar1_score 13 / bar2_score 16 / REWARD -1 / Q_MAX 6.032463e-01
# TIMESTEP 207841 / EPISODE 93 / bar1_score 14 / bar2_score 16 / REWARD 1 / Q_MAX 2.835328e+00
# TIMESTEP 207970 / EPISODE 93 / bar1_score 14 / bar2_score 17 / REWARD -1 / Q_MAX 6.451178e-01
# TIMESTEP 208099 / EPISODE 93 / bar1_score 15 / bar2_score 17 / REWARD 1 / Q_MAX 2.629347e+00
# TIMESTEP 208228 / EPISODE 93 / bar1_score 15 / bar2_score 18 / REWARD -1 / Q_MAX 5.431187e-01
# TIMESTEP 208357 / EPISODE 93 / bar1_score 16 / bar2_score 18 / REWARD 1 / Q_MAX 2.609185e+00
# TIMESTEP 208486 / EPISODE 93 / bar1_score 16 / bar2_score 19 / REWARD -1 / Q_MAX 4.190426e-01
# TIMESTEP 208615 / EPISODE 93 / bar1_score 17 / bar2_score 19 / REWARD 1 / Q_MAX 2.502815e+00
# TIMESTEP 208998 / EPISODE 93 / bar1_score 18 / bar2_score 19 / REWARD 1 / Q_MAX 2.437635e+00
# TIMESTEP 209296 / EPISODE 94 / bar1_score 0 / bar2_score 0 / REWARD -1 / Q_MAX 6.225631e-01
# TIMESTEP 209342 / EPISODE 94 / bar1_score 0 / bar2_score 1 / REWARD -1 / Q_MAX 5.931938e-01
# TIMESTEP 209471 / EPISODE 94 / bar1_score 1 / bar2_score 1 / REWARD 1 / Q_MAX 2.865646e+00
# TIMESTEP 209854 / EPISODE 94 / bar1_score 2 / bar2_score 1 / REWARD 1 / Q_MAX 2.824188e+00
# TIMESTEP 209983 / EPISODE 94 / bar1_score 2 / bar2_score 2 / REWARD -1 / Q_MAX 5.384890e-01
# TIMESTEP 210112 / EPISODE 94 / bar1_score 3 / bar2_score 2 / REWARD 1 / Q_MAX 2.747565e+00
# TIMESTEP 210410 / EPISODE 94 / bar1_score 3 / bar2_score 3 / REWARD -1 / Q_MAX 1.231623e+00
# TIMESTEP 210707 / EPISODE 94 / bar1_score 4 / bar2_score 3 / REWARD 1 / Q_MAX 2.206287e+00
# TIMESTEP 210836 / EPISODE 94 / bar1_score 4 / bar2_score 4 / REWARD -1 / Q_MAX 9.471815e-02
# TIMESTEP 210965 / EPISODE 94 / bar1_score 5 / bar2_score 4 / REWARD 1 / Q_MAX 2.388648e+00
# TIMESTEP 211348 / EPISODE 94 / bar1_score 6 / bar2_score 4 / REWARD 1 / Q_MAX 2.499167e+00
# TIMESTEP 211477 / EPISODE 94 / bar1_score 6 / bar2_score 5 / REWARD -1 / Q_MAX 2.233966e-01
# TIMESTEP 211608 / EPISODE 94 / bar1_score 7 / bar2_score 5 / REWARD 1 / Q_MAX 2.362366e+00
# TIMESTEP 211991 / EPISODE 94 / bar1_score 8 / bar2_score 5 / REWARD 1 / Q_MAX 2.431980e+00
# TIMESTEP 212120 / EPISODE 94 / bar1_score 8 / bar2_score 6 / REWARD -1 / Q_MAX 2.942390e-01
# TIMESTEP 212249 / EPISODE 94 / bar1_score 9 / bar2_score 6 / REWARD 1 / Q_MAX 2.387021e+00
# TIMESTEP 212378 / EPISODE 94 / bar1_score 9 / bar2_score 7 / REWARD -1 / Q_MAX 2.154955e-02
# TIMESTEP 212424 / EPISODE 94 / bar1_score 9 / bar2_score 8 / REWARD -1 / Q_MAX -1.567481e-01
# TIMESTEP 212721 / EPISODE 94 / bar1_score 10 / bar2_score 8 / REWARD 1 / Q_MAX 2.348304e+00
# TIMESTEP 212850 / EPISODE 94 / bar1_score 10 / bar2_score 9 / REWARD -1 / Q_MAX 3.073727e-01
# TIMESTEP 212979 / EPISODE 94 / bar1_score 11 / bar2_score 9 / REWARD 1 / Q_MAX 2.770928e+00
# TIMESTEP 213108 / EPISODE 94 / bar1_score 11 / bar2_score 10 / REWARD -1 / Q_MAX 1.013170e+00
# TIMESTEP 213239 / EPISODE 94 / bar1_score 12 / bar2_score 10 / REWARD 1 / Q_MAX 2.813432e+00
# TIMESTEP 213368 / EPISODE 94 / bar1_score 12 / bar2_score 11 / REWARD -1 / Q_MAX 6.994442e-01
# TIMESTEP 213497 / EPISODE 94 / bar1_score 13 / bar2_score 11 / REWARD 1 / Q_MAX 2.645064e+00
# TIMESTEP 213880 / EPISODE 94 / bar1_score 14 / bar2_score 11 / REWARD 1 / Q_MAX 2.293444e+00
# TIMESTEP 214009 / EPISODE 94 / bar1_score 14 / bar2_score 12 / REWARD -1 / Q_MAX 4.414782e-01
# TIMESTEP 214138 / EPISODE 94 / bar1_score 15 / bar2_score 12 / REWARD 1 / Q_MAX 2.412512e+00
# TIMESTEP 214267 / EPISODE 94 / bar1_score 15 / bar2_score 13 / REWARD -1 / Q_MAX 4.341450e-01
# TIMESTEP 214313 / EPISODE 94 / bar1_score 15 / bar2_score 14 / REWARD -1 / Q_MAX 1.815837e-01
# TIMESTEP 214613 / EPISODE 94 / bar1_score 16 / bar2_score 14 / REWARD 1 / Q_MAX 2.580328e+00
# TIMESTEP 214742 / EPISODE 94 / bar1_score 16 / bar2_score 15 / REWARD -1 / Q_MAX 1.092709e+00
# TIMESTEP 214871 / EPISODE 94 / bar1_score 17 / bar2_score 15 / REWARD 1 / Q_MAX 3.015626e+00
# TIMESTEP 215000 / EPISODE 94 / bar1_score 17 / bar2_score 16 / REWARD -1 / Q_MAX 1.151044e+00
# TIMESTEP 215131 / EPISODE 94 / bar1_score 18 / bar2_score 16 / REWARD 1 / Q_MAX 2.941074e+00
# TIMESTEP 215514 / EPISODE 94 / bar1_score 19 / bar2_score 16 / REWARD 1 / Q_MAX 2.747412e+00
# TIMESTEP 215896 / EPISODE 95 / bar1_score 0 / bar2_score 0 / REWARD 1 / Q_MAX 2.659808e+00
# TIMESTEP 216277 / EPISODE 95 / bar1_score 1 / bar2_score 0 / REWARD 1 / Q_MAX 2.833786e+00
# TIMESTEP 216406 / EPISODE 95 / bar1_score 1 / bar2_score 1 / REWARD -1 / Q_MAX 1.090466e+00
# TIMESTEP 216535 / EPISODE 95 / bar1_score 2 / bar2_score 1 / REWARD 1 / Q_MAX 2.695848e+00
# TIMESTEP 216917 / EPISODE 95 / bar1_score 3 / bar2_score 1 / REWARD 1 / Q_MAX 2.591462e+00
# TIMESTEP 217046 / EPISODE 95 / bar1_score 3 / bar2_score 2 / REWARD -1 / Q_MAX 7.889377e-01
# TIMESTEP 217092 / EPISODE 95 / bar1_score 3 / bar2_score 3 / REWARD -1 / Q_MAX -8.292954e-02
# TIMESTEP 217138 / EPISODE 95 / bar1_score 3 / bar2_score 4 / REWARD -1 / Q_MAX 7.846430e-02
# TIMESTEP 217184 / EPISODE 95 / bar1_score 3 / bar2_score 5 / REWARD -1 / Q_MAX -1.494537e-01
# TIMESTEP 217230 / EPISODE 95 / bar1_score 3 / bar2_score 6 / REWARD -1 / Q_MAX 8.311199e-02
# TIMESTEP 217359 / EPISODE 95 / bar1_score 4 / bar2_score 6 / REWARD 1 / Q_MAX 2.373467e+00
# TIMESTEP 217740 / EPISODE 95 / bar1_score 5 / bar2_score 6 / REWARD 1 / Q_MAX 2.457487e+00
# TIMESTEP 217869 / EPISODE 95 / bar1_score 5 / bar2_score 7 / REWARD -1 / Q_MAX 1.327372e-01
# TIMESTEP 217998 / EPISODE 95 / bar1_score 6 / bar2_score 7 / REWARD 1 / Q_MAX 2.501313e+00
